# %%
def explore_data(dataset,start,end,rows_and_columns=False):
    dataset_slice=dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')
    if rows_and_columns:
        print('Number of rows:',len(dataset))
        print('Number of columns:',len(dataset[0]))

# %%
from csv import reader
opened_file = open('googleplaystore.csv', encoding="cp437", errors='ignore')
read_file=reader(opened_file)
android=list(read_file)
android_header=android[0]
android=android[1:]

# %%
from csv import reader
opened_file = open('AppleStore.csv', encoding="cp437", errors='ignore')
read_file=reader(opened_file)
Apple=list(read_file)
Apple_header=Apple[0]
Apple=Apple[1:]

# %%
print(android_header)
print('\n')
explore_data(android,0,2,True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# Number of rows: 10840
# Number of columns: 13

# %%
print(android[10472])
print('\n')
print(android_header)
print('\n')
print(android[0])
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
#
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']

# %%
print(android[10472])
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %%
android.remove(android[10472])

# %%
print(android[10472])
# Out:
# ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up']

# %%
duplicate_apps=[]
unique_apps=[]
for app in android:
    name=app[0]
    if name in unique_apps:
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)
print("Number of duplicate apps:" , len(duplicate_apps))   
print('\n')
print("unique apps:",unique_apps)
print('\n')
print("Examples of duplicate apps:",duplicate_apps[:5])
# Out:
# Number of duplicate apps: 1181
#
#
# unique apps: ['Photo Editor & Candy Camera & Grid & ScrapBook', 'Coloring book moana', 'U Launcher Lite ΓÇô FREE Live Cool Themes, Hide Apps', 'Sketch - Draw & Paint', 'Pixel Draw - Number Art Coloring Book', 'Paper flowers instructions', 'Smoke Effect Photo Maker - Smoke Editor', 'Infinite Painter', 'Garden Coloring Book', 'Kids Paint Free - Drawing Fun', 'Text on Photo - Fonteee', 'Name Art Photo Editor - Focus n Filters', 'Tattoo Name On My Photo Editor', 'Mandala Coloring Book', '3D Color Pixel by Number - Sandbox Art Coloring', 'Learn To Draw Kawaii Characters', 'Photo Designer - Write your
selfie, beauty camera, photo editor', 'Mirror - Zoom & Exposure -', 'Beauty Selfie Camera', 'Hairstyles step by step', 'Filters for Selfie', 'Tie - Always be happy', 'Ulta Beauty', 'Prom MakeUp Tutorial', 'Selfie Camera', 'Sweet Selfie Beauty Camera', 'Colors of white in Urdu', 'Selfie Camera Photo Editor & Filter & Sticker', 'Wrinkles and rejuvenation', 'Eyes Makeup Beauty Tip ...
#
#
# Examples of duplicate apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings']

# %%
for app in android:
    name = app[0]
    if name =='Instagram':
        print(app)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %%
apple_duplicate_apps=[]
apple_unique_apps=[]
for app in Apple:
    name=app[2]
    if name in apple_unique_apps:
        apple_duplicate_apps.append(name)
    else:
        apple_unique_apps.append(name)
print("Number of duplicate apps:" , len(apple_duplicate_apps))   
print('\n')
print("unique apps:",apple_unique_apps)
print('\n')
print("Examples of duplicate apps:",apple_duplicate_apps[:5])
# Out:
# Number of duplicate apps: 2
#
#
# unique apps: ['PAC-MAN Premium', 'Evernote - stay organized', 'WeatherBug - Local Weather, Radar, Maps, Alerts', 'eBay: Best App to Buy, Sell, Save! Online Shopping', 'Bible', 'Shanghai Mahjong', 'PayPal - Send and request money safely', 'Pandora - Music & Radio', 'PCalc - The Best Calculator', 'Ms. PAC-MAN', 'Solitaire by MobilityWare', 'SCRABBLE Premium', 'Google ΓÇô Search made just for mobile', 'Bank of America - Mobile Banking', 'FreeCell', 'TripAdvisor Hotels Flights Restaurants', 'Facebook', 'Yelp - Nearby Restaurants, Shopping & Services', 'Shazam - Discover music, artists, videos & lyrics', 'Crash Bandicoot Nitro Kart 3D', 'iQuran', ':) Sudoku +', 'Yahoo Sports - Teams, Scores, News & Highlights', 'Mileage Log | Fahrtenbuch', 'Cleartune - Chromatic Tuner', 'Lifesum ΓÇô Inspiring healthy lifestyle app', 'Hangman.', 'iTranslate - Language Translator & Dictionary', 'TouchOSC', 'RadarScope', 'LinkedIn', 'Period Tracker Deluxe', 'Election 2016 Map', 'Blackjack by MobilityWare', 'White Noise', 'iHeartRadio ΓÇô Free Music & Radio Stations', 'Line Rider iRideΓäó', 'Deliveries: a package tracker', 'Hurricane Pro', 'Fieldrunners', 'Juxtaposer', 'Deezer - Listen to your Favorite Music & Playlists', 'iStellar', 'Sonos Controller', 'Avertinoo', 'Google Earth', 'iFart - The Original Fart Sounds App', 'PAC-MAN', 'FOX Sports Mobile', 'First Words Animals', 'We
#
#
# Examples of duplicate apps: ['VR Roller Coaster', 'Mannequin Challenge']

# %%
reviews_max={}
for app in android:
    app_name=app[0]
    n_reviews = app[3]
    if app_name in reviews_max and reviews_max[app_name]<n_reviews:
        reviews_max[app_name]=n_reviews
    elif app_name not in reviews_max:
         reviews_max[app_name]=n_reviews

# %%
android_clean =[]
already_added =[]
for app in android :
    name = app[0]
    n_reviews = app[3]
    if (reviews_max[name] == n_reviews)and(name not in already_added):
        android_clean.append(app)
        already_added.append(app)
print(len(android_clean))
print('\n')
print(len(already_added))
print('\n')
print(len(android))
# Out:
# 10055
#
#
# 10055
#
#
# 10840

# %%
explore_data(android_clean ,0,3,True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite ΓÇô FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9660
# Number of columns: 13

# %%
apple_reviews_max={}
for app in Apple:
    app_name=app[2]
    n_reviews = app[5]
    if app_name in apple_reviews_max and apple_reviews_max[app_name]<n_reviews:
        apple_reviews_max[app_name]=n_reviews
    elif app_name not in apple_reviews_max:
         apple_reviews_max[app_name]=n_reviews

# %%
apple_clean =[]
app_already_added =[]
for app in Apple :
    app_name = app[2]
    n_reviews = app[6]
    if (apple_reviews_max[app_name] == n_reviews)and(app_name not in app_already_added ):
        apple_clean.append(app)
        app_already_added.append(app_name)
print(len(apple_clean))
print('\n')
print(len(app_already_added))
print('\n')
print(len(Apple))
# Out:
# 673
#
#
# 673
#
#
# 7197

# %%
explore_data(apple_clean ,0,3,True)
# Out:
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# Number of rows: 7197
# Number of columns: 17

# %%
def is_english_app(string):
    for char in string:
        if ord(char)>127:
            return False
    return True

# %%
is_english_app('Instagram')
# Out:
# True

# %%
is_english_app('爱奇艺PPS -《欢乐颂2》电视剧热播')
# Out:
# False

# %%
is_english_app('Instachat 😜')
# Out:
# False

# %%
is_english_app( 'Docs To Go™  Free Office Suite')
# Out:
# False

# %%
def is_semi_english_app(string):
    non_english_char=0
    for char in string:
        if ord(char) > 127:
            non_english_char += 1
    if non_english_char > 3:
        return False
    else:
        return True

# %%
is_semi_english_app('Instachat 😜')
# Out:
# True

# %%
is_semi_english_app('爱奇艺PPS -《欢乐颂2》电视剧热播')
# Out:
# False

# %%
android_english_app=[]
for app in android_clean:
    android_app_name =app[0]
    if is_semi_english_app(app_name):
        android_english_app.append(app)
print(len(android_english_app))
#print(len(android_clean))
#print(len(android_clean)-len(android_english_app))
#########      
apple_english_app=[]
for app in apple_clean:
    apple_app_name =app[2]
    if is_semi_english_app(apple_app_name):
        apple_english_app.append(app)   
print(len(apple_english_app))  
#print(len(Apple)) 
#0print(len(apple_clean)-len(apple_english_app))
# Out:
# 10055
# 10055
# 0
# 130
# 7197
# 543

# %%
android_english_app=[]
for app in android_clean:
    android_app_name =app[0]
    if is_semi_english_app(android_app_name):
        android_english_app.append(app)
print(len(android_english_app))
##########        
apple_english_app=[]
for app in apple_clean:
    apple_app_name =app[2]
    if is_semi_english_app(apple_app_name):
        apple_english_app.append(app)   
print(len(apple_english_app))
# Out:
# 9895
# 130

# %%
explore_data(android_english_app ,0,3,True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite ΓÇô FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9895
# Number of columns: 13

# %%
explore_data(apple_english_app ,0,3,True)
# Out:
# ['604', '391947489', 'iSleeping by iSommeil SARL', '24419328', 'USD', '0', '0', '0', '0', '0', '2.7.1', '4+', 'Medical', '38', '0', '3', '1']
#
#
# ['1225', '479159684', 'My au', '50800640', 'USD', '0', '0', '0', '0', '0', '6.1.0', '4+', 'Utilities', '37', '4', '2', '1']
#
#
# ['1269', '482917268', 'PetitLyrics', '40871936', 'USD', '0', '0', '0', '0', '0', '2.4.5', '4+', 'Music', '37', '4', '2', '1']
#
#
# Number of rows: 130
# Number of columns: 17

# %%
android_free_app=[]
android_non_free_app=[]
for app in android :
    app_price = app[7]
    if app_price=='0':
        android_free_app.append(app)
    else:
        android_non_free_app.append(app)

# %%
len(android_free_app)
# Out:
# 10040

# %%
len(android_non_free_app)
# Out:
# 800

# %%
len(android)
# Out:
# 10840

# %%
apple_free_app=[]
apple_non_free_app=[]
for app in Apple :
    apple_price = app[5]
    if apple_price =='0':
        apple_free_app.append(app)
    else:
        apple_non_free_app.append(app)

# %%
len(apple_free_app)
# Out:
# 4056

# %%
len(apple_non_free_app)
# Out:
# 3141

# %%
len(Apple)
# Out:
# 7197
